# %% [markdown]
# # 4.8 Task - Grouping Data & Aggregating Variables
#
# ## This script contains the following points:
#
# #### 1. Import libraries and dataframe
# #### 2. Reducing the data format
# #### 3. Aggregated mean for entire dataframe
# #### 4. Aggregating Data with transform()
# #### 5. Deriving Columns with loc()
# #### 6. Create a spending flag
# #### 7. Create an order frequency flag

# %% [markdown]
# #### 1. Import libraries and dataframe

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Defining path and import dataframe
path=r'C:\Users\olilo\OneDrive\Dokumente\CF\Data Analytics Immersion_Week 8-12\2023-08-28 Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_new_columns.pkl'))

# %%
# Output check
ords_prods_merge.shape
# Out:
# (32404859, 20)

# %% [markdown]
# #### 2. Reducing the data format

# %%
# Information about data size
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 20 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  _merge                  category
#  15   price_range_loc        object
#  16  price_range_loc         object
#  17  busiest_day             object
#  18  busiest_days            object
#  19  busiest_period_of_day   object
# dtypes: category(1), float64(2), int64(10), object(7)
# memory usage: 4.6+ GB

# %%
# Checking the information
ords_prods_merge.tail(5)
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 32404854   1320836   202557    prior            17          2
# 32404855     31526   202557    prior            18          5
# 32404856    758936   203436    prior             1          2
# 32404857   2745165   203436    prior             2          3
# 32404858   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 32404854                 15                     1.0       43553
# 32404855                 11                     3.0       43553
# 32404856                  7                     NaN       42338
# 32404857                  5                    15.0       42338
# 32404858                 14                     NaN       28818
#
#           add_to_cart_order  reordered                   product_name  \
# 32404854                  2          1            Orange Energy Shots
# 32404855                  2          1            Orange Energy Shots
# 32404856                  4          0          Zucchini Chips, Pesto
# 32404857                 16          1          Zucchini Chips, Pesto
# 32404858                  8          0  Hot Oatmeal Multigrain Raisin
#
#           aisle_id  department_id  prices _merge  price_range_loc  \
# 32404854        64              7     3.7   both              NaN
# 32404855        64              7     3.7   both              NaN
# 32404856        50             19     6.9   both              NaN
# 32404857        50             19     6.9   both              NaN
# 32404858       130             14    10.3   both              NaN
#
#             price_range_loc     busiest_day         busiest_days  \
# 32404854  Low-range product  Regularly busy  Regularly busy days
# 32404855  Low-range product  Regularly busy  Regularly busy days
# 32404856  Mid-range product  Regularly busy  Regularly busy days
# 32404857  Mid-range product  Regularly busy      Least busy days
# 32404858  Mid-range product      Least busy      Least busy days
#
#          busiest_period_of_day
# 32404854           Most orders
# 32404855           Most orders
# 32404856        Average orders
# 32404857         Fewest orders
# 32404858           Most orders

# %%
#Reducing the data format
ords_prods_merge['order_number'] = ords_prods_merge['order_number'].astype('uint8')

# %%
ords_prods_merge['order_dow'] = ords_prods_merge['order_dow'].astype('uint8')

# %%
ords_prods_merge['order_hour_of_day'] = ords_prods_merge['order_hour_of_day'].astype('uint8')

# %%
ords_prods_merge['reordered'] = ords_prods_merge['reordered'].astype('uint8')

# %%
ords_prods_merge['department_id'] = ords_prods_merge['department_id'].astype('uint8')

# %%
ords_prods_merge['product_id'] = ords_prods_merge['product_id'].astype('uint32')

# %%
# Information about data size after reduction
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 20 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            uint8
#  4   order_dow               uint8
#  5   order_hour_of_day       uint8
#  6   days_since_prior_order  float64
#  7   product_id              uint32
#  8   add_to_cart_order       int64
#  9   reordered               uint8
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           uint8
#  13  prices                  float64
#  14  _merge                  category
#  15   price_range_loc        object
#  16  price_range_loc         object
#  17  busiest_day             object
#  18  busiest_days            object
#  19  busiest_period_of_day   object
# dtypes: category(1), float64(2), int64(4), object(7), uint32(1), uint8(5)
# memory usage: 3.4+ GB

# %% [markdown]
# #### 3. Aggregated mean for entire dataframe

# %%
# Aggregated mean of the “order_number” column grouped by “department_id” for whole dataframe
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
# Tests for proving a significant difference between the means of different groups
# Using the mean() function to achieve the same results 
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# Results from df.groupby('department_id')['order_number'].mean(), as a sample:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64
#
# The values differ from each other in some cases only slightly, such as in the department_id 4 sample (18.825780), and department_id 4 ( 17.811403) of the entire dataframe. Comparing that the sample had a million columns, the full dataframe has 32.404.859 the difference betwwwn means is small.

# %% [markdown]
# #### 4. Aggregating Data with transform()

# %%
# Split the data into groups
# Apply the transform() function
# Create a new column,'max_order'
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check out the results
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# 11   1870022       15    prior            17          2                 16
# 12   1911383       15    prior            18          2                 11
# 13   2715276       15    prior            21          1                  9
# 14    487368       15    prior            22          1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                      NaN         196                  1          0  ...
# 1                     15.0         196                  1          1  ...
# 2                     21.0         196                  1          1  ...
# 3                     29.0         196                  1          1  ...
# 4                     28.0         196                  1          1  ...
# 5                     19.0         196                  1          1  ...
# 6                     20.0         196                  1          1  ...
# 7                     14.0         196                  2          1  ...
# 8                      0.0         196                  4          1  ...
# 9                     30.0         196                  1          1  ...
# 10                     7.0         196                  2          0  ...
# 11                     8.0         196                  6          1  ...
# 12                     7.0         196                  1          1  ...
# 13                     7.0         196                  1          1  ...
# 14                    14.0         196                  1          1  ...
#
#    aisle_id  department_id  prices  _merge  price_range_loc  \
# 0        77              7     9.0    both              NaN
# 1        77              7     9.0    both              NaN
# 2        77              7     9.0    both              NaN
# 3        77              7     9.0    both              NaN
# 4        77              7     9.0    both              NaN
# 5        77              7     9.0    both              NaN
# 6        77              7     9.0    both              NaN
# 7        77              7     9.0    both              NaN
# 8        77              7     9.0    both              NaN
# 9        77              7     9.0    both              NaN
# 10       77              7     9.0    both              NaN
# 11       77              7     9.0    both              NaN
# 12       77              7     9.0    both              NaN
# 13       77              7     9.0    both              NaN
# 14       77              7     9.0    both              NaN
#
#       price_range_loc     busiest_day         busiest_days  \
# 0   Mid-range product  Regularly busy  Regularly busy days
# 1   Mid-range product  Regularly busy      Least busy days
# 2   Mid-range product  Regularly busy      Least busy days
# 3   Mid-range product      Least busy      Least busy days
# 4   Mid-range product      Least busy      Least busy days
# 5   Mid-range product  Regularly busy  Regularly busy days
# 6   Mid-range product  Regularly busy         Busiest days
# 7   Mid-range product  Regularly busy         Busiest days
# 8   Mid-range product  Regularly busy         Busiest days
# 9   Mid-range product      Least busy      Least busy days
# 10  Mid-range product  Regularly busy         Busiest days
# 11  Mid-range product  Regularly busy  Regularly busy days
# 12  Mid-range product  Regularly busy  Regularly busy days
# 13  Mid-range product  Regularly busy         Busiest days
# 14  Mid-range product  Regularly busy         Busiest days
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2            Most orders        10
# 3         Average orders        10
# 4            Most orders        10
# 5         Average orders        10
# 6            Most orders        10
# 7            Most orders        10
# 8            Most orders        10
# 9         Average orders        10
# 10           Most orders        22
# 11           Most orders        22
# 12           Most orders        22
# 13           Most orders        22
# 14           Most orders        22
#
# [15 rows x 21 columns]

# %%
# Command to assign any options regarding the maximum number of rows
pd.options.display.max_rows = None

# %%
# Checking output again
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# 11   1870022       15    prior            17          2                 16
# 12   1911383       15    prior            18          2                 11
# 13   2715276       15    prior            21          1                  9
# 14    487368       15    prior            22          1                 10
# 15   2293453       19    prior             2          5                 14
# 16   1973799       19    prior             5          6                 12
# 17    532817       19    prior             7          4                 17
# 18   1573906       21    prior            10          3                 10
# 19   1593000       31    prior            10          3                  8
# 20   2231262       31    prior            17          3                 11
# 21   2580647       43    prior             6          4                 16
# 22   2187180       43    prior             9          4                 12
# 23   2497897       52    prior             1          1                  9
# 24   1318871       52    prior             2          1                 10
# 25   1261384       52    prior             3          1                 10
# 26    580568       52    prior             5          2                 10
# 27   2428073       52    prior             7          2                  7
# 28    342306       52    prior             9          1                 11
# 29   1520353       52    prior            10          2                 10
# 30   2542086       52    prior            11          2                  9
# 31    944694       52    prior            12          1                 16
# 32   1268191       52    prior            15          2                 11
# 33   1122089       52    prior            17          2                 10
# 34   1498922       52    prior            18          2                 10
# 35    180919       52    prior            19          3                  8
# 36   2695875       52    prior            21          5                 10
# 37   3205960       67    prior             1          3                 11
# 38    970922       67    prior             2          1                 15
# 39    596585       67    prior             3          1                 13
# 40   2037087       67    prior             4          2                  9
# 41   2474111       67    prior             5          3                 14
# 42   1568481       67    prior             6          3                 12
# 43   2048527       67    prior             8          2                 11
# 44   2389031       67    prior             9          2                 14
# 45   2378562       67    prior            10          1                 10
# 46   1515698       67    prior            11          1                 11
# 47   1928050       67    prior            12          2                 12
# 48   1949274       67    prior            13          1                 10
# 49    551869       67    prior            14          1                  9
# 50    768572       67    prior            16          4                 10
# 51    150528       67    prior            18          5                 16
# 52     29758       67    prior            19          0                 14
# 53   1558976       67    prior            21          1                  9
# 54    863974       67    prior            22          1                 11
# 55   2308399       67    prior            23          1                 14
# 56   2759128       81    prior             3          1                  9
# 57   1812985       81    prior             5          2                 20
# 58   1889835       82    prior             1          3                 15
# 59    499460       82    prior             3          5                 10
# 60   2728456       82    prior             4          0                 11
# 61   2653743       82    prior             6          4                  9
# 62   1358880       82    prior             9          1                 10
# 63    343588       82    prior            10          2                 11
# 64   3034663       82    prior            15          2                 11
# 65    147262       82    prior            18          1                 13
# 66   3144004       82    prior            19          2                 15
# 67   2126069       98    prior             3          0                  9
# 68   2210120       98    prior             7          5                 14
# 69    681011       98    prior             9          3                  9
# 70   2846344       98    prior            11          4                 13
# 71    747431       98    prior            12          6                 13
# 72   2383054       98    prior            13          4                 11
# 73   1993729       98    prior            14          5                  8
# 74   1403849      109    prior             3          3                 17
# 75    520620      120    prior             1          3                 11
# 76   3273029      120    prior             3          2                  8
# 77   1861943      185    prior             2          1                 12
# 78   2040988      195    prior             1          1                 14
# 79   1680569      195    prior             8          1                  9
# 80    276171      195    prior            19          5                 11
# 81   2744976      195    prior            22          5                 10
# 82   2781919      195    prior            25          1                 14
# 83   1738718      195    prior            31          2                  8
# 84   3058369      195    prior            34          3                 10
# 85   1485596      195    prior            37          2                 15
# 86    417035      195    prior            40          3                 16
# 87   1615297      195    prior            47          5                 10
# 88   1765587      195    prior            52          3                 12
# 89    745908      195    prior            57          4                 11
# 90   2505656      222    prior            17          2                 12
# 91   3268370      222    prior            38          5                 15
# 92   2016711      290    prior             9          5                 19
# 93   2706088      290    prior            28          6                 10
# 94   1952286      331    prior             6          5                 16
# 95   3226575      360    prior             1          5                 12
# 96   1469869      377    prior             3          5                 17
# 97   1927023      387    prior             2          4                 10
# 98    858092      420    prior             4          1                 19
# 99    119314      420    prior             5          3                 19
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                      NaN         196                  1          0  ...
# 1                     15.0         196                  1          1  ...
# 2                     21.0         196                  1          1  ...
# 3                     29.0         196                  1          1  ...
# 4                     28.0         196                  1          1  ...
# 5                     19.0         196                  1          1  ...
# 6                     20.0         196                  1          1  ...
# 7                     14.0         196                  2          1  ...
# 8                      0.0         196                  4          1  ...
# 9                     30.0         196                  1          1  ...
# 10                     7.0         196                  2          0  ...
# 11                     8.0         196                  6          1  ...
# 12                     7.0         196                  1          1  ...
# 13                     7.0         196                  1          1  ...
# 14                    14.0         196                  1          1  ...
# 15                     6.0         196                  3          0  ...
# 16                     8.0         196                 15          1  ...
# 17                     6.0         196                  1          1  ...
# 18                     6.0         196                  2          0  ...
# 19                     7.0         196                 17          0  ...
# 20                     8.0         196                 14          1  ...
# 21                     4.0         196                  9          0  ...
# 22                     3.0         196                  1          1  ...
# 23                     NaN         196                  4          0  ...
# 24                     7.0         196                  5          1  ...
# 25                     7.0         196                  3          1  ...
# 26                     8.0         196                  6          1  ...
# 27                     8.0         196                  5          1  ...
# 28                     7.0         196                  5          1  ...
# 29                     8.0         196                  4          1  ...
# 30                     7.0         196                  3          1  ...
# 31                     6.0         196                  7          1  ...
# 32                     8.0         196                  3          1  ...
# 33                     6.0         196                  4          1  ...
# 34                    14.0         196                  6          1  ...
# 35                     8.0         196                  4          1  ...
# 36                    30.0         196                  1          1  ...
# 37                     NaN         196                  1          0  ...
# 38                     5.0         196                  2          1  ...
# 39                     7.0         196                  2          1  ...
# 40                     8.0         196                  1          1  ...
# 41                     8.0         196                  2          1  ...
# 42                     7.0         196                  2          1  ...
# 43                     7.0         196                  1          1  ...
# 44                     7.0         196                  1          1  ...
# 45                     6.0         196                  1          1  ...
# 46                     7.0         196                  1          1  ...
# 47                     8.0         196                  1          1  ...
# 48                     6.0         196                  1          1  ...
# 49                     7.0         196                  1          1  ...
# 50                     9.0         196                  1          1  ...
# 51                     4.0         196                  1          1  ...
# 52                     9.0         196                  2          1  ...
# 53                     5.0         196                  2          1  ...
# 54                    14.0         196                  3          1  ...
# 55                    14.0         196                  1          1  ...
# 56                    14.0         196                  2          0  ...
# 57                    30.0         196                  1          1  ...
# 58                     NaN         196                  6          0  ...
# 59                     5.0         196                  2          1  ...
# 60                    16.0         196                  1          1  ...
# 61                    13.0         196                  5          1  ...
# 62                    30.0         196                  1          1  ...
# 63                     1.0         196                  1          1  ...
# 64                    12.0         196                  1          1  ...
# 65                     7.0         196                  1          1  ...
# 66                     8.0         196                  1          1  ...
# 67                    25.0         196                  7          0  ...
# 68                     5.0         196                  1          1  ...
# 69                    30.0         196                  1          1  ...
# 70                    15.0         196                  2          1  ...
# 71                    30.0         196                  4          1  ...
# 72                    30.0         196                  1          1  ...
# 73                     8.0         196                  2          1  ...
# 74                     9.0         196                  5          0  ...
# 75                     NaN         196                  2          0  ...
# 76                    19.0         196                  2          1  ...
# 77                    25.0         196                 10          0  ...
# 78                     NaN         196                  2          0  ...
# 79                     4.0         196                  2          1  ...
# 80                     3.0         196                  2          1  ...
# 81                     7.0         196                  2          1  ...
# 82                     4.0         196                  1          1  ...
# 83                     4.0         196                  2          1  ...
# 84                     6.0         196                  2          1  ...
# 85                     0.0         196                  2          1  ...
# 86                     2.0         196                  2          1  ...
# 87                     2.0         196                  2          1  ...
# 88                     2.0         196                  3          1  ...
# 89                     3.0         196                  3          1  ...
# 90                     1.0         196                  2          0  ...
# 91                     1.0         196                  6          1  ...
# 92                     6.0         196                  8          0  ...
# 93                     7.0         196                 16          1  ...
# 94                    30.0         196                  8          0  ...
# 95                     NaN         196                  1          0  ...
# 96                     3.0         196                  9          0  ...
# 97                    22.0         196                  3          0  ...
# 98                    30.0         196                  2          0  ...
# 99                    16.0         196                  2          1  ...
#
#    aisle_id  department_id  prices  _merge  price_range_loc  \
# 0        77              7     9.0    both              NaN
# 1        77              7     9.0    both              NaN
# 2        77              7     9.0    both              NaN
# 3        77              7     9.0    both              NaN
# 4        77              7     9.0    both              NaN
# 5        77              7     9.0    both              NaN
# 6        77              7     9.0    both              NaN
# 7        77              7     9.0    both              NaN
# 8        77              7     9.0    both              NaN
# 9        77              7     9.0    both              NaN
# 10       77              7     9.0    both              NaN
# 11       77              7     9.0    both              NaN
# 12       77              7     9.0    both              NaN
# 13       77              7     9.0    both              NaN
# 14       77              7     9.0    both              NaN
# 15       77              7     9.0    both              NaN
# 16       77              7     9.0    both              NaN
# 17       77              7     9.0    both              NaN
# 18       77              7     9.0    both              NaN
# 19       77              7     9.0    both              NaN
# 20       77              7     9.0    both              NaN
# 21       77              7     9.0    both              NaN
# 22       77              7     9.0    both              NaN
# 23       77              7     9.0    both              NaN
# 24       77              7     9.0    both              NaN
# 25       77              7     9.0    both              NaN
# 26       77              7     9.0    both              NaN
# 27       77              7     9.0    both              NaN
# 28       77              7     9.0    both              NaN
# 29       77              7     9.0    both              NaN
# 30       77              7     9.0    both              NaN
# 31       77              7     9.0    both              NaN
# 32       77              7     9.0    both              NaN
# 33       77              7     9.0    both              NaN
# 34       77              7     9.0    both              NaN
# 35       77              7     9.0    both              NaN
# 36       77              7     9.0    both              NaN
# 37       77              7     9.0    both              NaN
# 38       77              7     9.0    both              NaN
# 39       77              7     9.0    both              NaN
# 40       77              7     9.0    both              NaN
# 41       77              7     9.0    both              NaN
# 42       77              7     9.0    both              NaN
# 43       77              7     9.0    both              NaN
# 44       77              7     9.0    both              NaN
# 45       77              7     9.0    both              NaN
# 46       77              7     9.0    both              NaN
# 47       77              7     9.0    both              NaN
# 48       77              7     9.0    both              NaN
# 49       77              7     9.0    both              NaN
# 50       77              7     9.0    both              NaN
# 51       77              7     9.0    both              NaN
# 52       77              7     9.0    both              NaN
# 53       77              7     9.0    both              NaN
# 54       77              7     9.0    both              NaN
# 55       77              7     9.0    both              NaN
# 56       77              7     9.0    both              NaN
# 57       77              7     9.0    both              NaN
# 58       77              7     9.0    both              NaN
# 59       77              7     9.0    both              NaN
# 60       77              7     9.0    both              NaN
# 61       77              7     9.0    both              NaN
# 62       77              7     9.0    both              NaN
# 63       77              7     9.0    both              NaN
# 64       77              7     9.0    both              NaN
# 65       77              7     9.0    both              NaN
# 66       77              7     9.0    both              NaN
# 67       77              7     9.0    both              NaN
# 68       77              7     9.0    both              NaN
# 69       77              7     9.0    both              NaN
# 70       77              7     9.0    both              NaN
# 71       77              7     9.0    both              NaN
# 72       77              7     9.0    both              NaN
# 73       77              7     9.0    both              NaN
# 74       77              7     9.0    both              NaN
# 75       77              7     9.0    both              NaN
# 76       77              7     9.0    both              NaN
# 77       77              7     9.0    both              NaN
# 78       77              7     9.0    both              NaN
# 79       77              7     9.0    both              NaN
# 80       77              7     9.0    both              NaN
# 81       77              7     9.0    both              NaN
# 82       77              7     9.0    both              NaN
# 83       77              7     9.0    both              NaN
# 84       77              7     9.0    both              NaN
# 85       77              7     9.0    both              NaN
# 86       77              7     9.0    both              NaN
# 87       77              7     9.0    both              NaN
# 88       77              7     9.0    both              NaN
# 89       77              7     9.0    both              NaN
# 90       77              7     9.0    both              NaN
# 91       77              7     9.0    both              NaN
# 92       77              7     9.0    both              NaN
# 93       77              7     9.0    both              NaN
# 94       77              7     9.0    both              NaN
# 95       77              7     9.0    both              NaN
# 96       77              7     9.0    both              NaN
# 97       77              7     9.0    both              NaN
# 98       77              7     9.0    both              NaN
# 99       77              7     9.0    both              NaN
#
#       price_range_loc     busiest_day         busiest_days  \
# 0   Mid-range product  Regularly busy  Regularly busy days
# 1   Mid-range product  Regularly busy      Least busy days
# 2   Mid-range product  Regularly busy      Least busy days
# 3   Mid-range product      Least busy      Least busy days
# 4   Mid-range product      Least busy      Least busy days
# 5   Mid-range product  Regularly busy  Regularly busy days
# 6   Mid-range product  Regularly busy         Busiest days
# 7   Mid-range product  Regularly busy         Busiest days
# 8   Mid-range product  Regularly busy         Busiest days
# 9   Mid-range product      Least busy      Least busy days
# 10  Mid-range product  Regularly busy         Busiest days
# 11  Mid-range product  Regularly busy  Regularly busy days
# 12  Mid-range product  Regularly busy  Regularly busy days
# 13  Mid-range product  Regularly busy         Busiest days
# 14  Mid-range product  Regularly busy         Busiest days
# 15  Mid-range product  Regularly busy  Regularly busy days
# 16  Mid-range product  Regularly busy  Regularly busy days
# 17  Mid-range product      Least busy      Least busy days
# 18  Mid-range product  Regularly busy      Least busy days
# 19  Mid-range product  Regularly busy      Least busy days
# 20  Mid-range product  Regularly busy      Least busy days
# 21  Mid-range product      Least busy      Least busy days
# 22  Mid-range product      Least busy      Least busy days
# 23  Mid-range product  Regularly busy         Busiest days
# 24  Mid-range product  Regularly busy         Busiest days
# 25  Mid-range product  Regularly busy         Busiest days
# 26  Mid-range product  Regularly busy  Regularly busy days
# 27  Mid-range product  Regularly busy  Regularly busy days
# 28  Mid-range product  Regularly busy         Busiest days
# 29  Mid-range product  Regularly busy  Regularly busy days
# 30  Mid-range product  Regularly busy  Regularly busy days
# 31  Mid-range product  Regularly busy         Busiest days
# 32  Mid-range product  Regularly busy  Regularly busy days
# 33  Mid-range product  Regularly busy  Regularly busy days
# 34  Mid-range product  Regularly busy  Regularly busy days
# 35  Mid-range product  Regularly busy      Least busy days
# 36  Mid-range product  Regularly busy  Regularly busy days
# 37  Mid-range product  Regularly busy      Least busy days
# 38  Mid-range product  Regularly busy         Busiest days
# 39  Mid-range product  Regularly busy         Busiest days
# 40  Mid-range product  Regularly busy  Regularly busy days
# 41  Mid-range product  Regularly busy      Least busy days
# 42  Mid-range product  Regularly busy      Least busy days
# 43  Mid-range product  Regularly busy  Regularly busy days
# 44  Mid-range product  Regularly busy  Regularly busy days
# 45  Mid-range product  Regularly busy         Busiest days
# 46  Mid-range product  Regularly busy         Busiest days
# 47  Mid-range product  Regularly busy  Regularly busy days
# 48  Mid-range product  Regularly busy         Busiest days
# 49  Mid-range product  Regularly busy         Busiest days
# 50  Mid-range product      Least busy      Least busy days
# 51  Mid-range product  Regularly busy  Regularly busy days
# 52  Mid-range product     Busiest day         Busiest days
# 53  Mid-range product  Regularly busy         Busiest days
# 54  Mid-range product  Regularly busy         Busiest days
# 55  Mid-range product  Regularly busy         Busiest days
# 56  Mid-range product  Regularly busy         Busiest days
# 57  Mid-range product  Regularly busy  Regularly busy days
# 58  Mid-range product  Regularly busy      Least busy days
# 59  Mid-range product  Regularly busy  Regularly busy days
# 60  Mid-range product     Busiest day         Busiest days
# 61  Mid-range product      Least busy      Least busy days
# 62  Mid-range product  Regularly busy         Busiest days
# 63  Mid-range product  Regularly busy  Regularly busy days
# 64  Mid-range product  Regularly busy  Regularly busy days
# 65  Mid-range product  Regularly busy         Busiest days
# 66  Mid-range product  Regularly busy  Regularly busy days
# 67  Mid-range product     Busiest day         Busiest days
# 68  Mid-range product  Regularly busy  Regularly busy days
# 69  Mid-range product  Regularly busy      Least busy days
# 70  Mid-range product      Least busy      Least busy days
# 71  Mid-range product  Regularly busy  Regularly busy days
# 72  Mid-range product      Least busy      Least busy days
# 73  Mid-range product  Regularly busy  Regularly busy days
# 74  Mid-range product  Regularly busy      Least busy days
# 75  Mid-range product  Regularly busy      Least busy days
# 76  Mid-range product  Regularly busy  Regularly busy days
# 77  Mid-range product  Regularly busy         Busiest days
# 78  Mid-range product  Regularly busy         Busiest days
# 79  Mid-range product  Regularly busy         Busiest days
# 80  Mid-range product  Regularly busy  Regularly busy days
# 81  Mid-range product  Regularly busy  Regularly busy days
# 82  Mid-range product  Regularly busy         Busiest days
# 83  Mid-range product  Regularly busy  Regularly busy days
# 84  Mid-range product  Regularly busy      Least busy days
# 85  Mid-range product  Regularly busy  Regularly busy days
# 86  Mid-range product  Regularly busy      Least busy days
# 87  Mid-range product  Regularly busy  Regularly busy days
# 88  Mid-range product  Regularly busy      Least busy days
# 89  Mid-range product      Least busy      Least busy days
# 90  Mid-range product  Regularly busy  Regularly busy days
# 91  Mid-range product  Regularly busy  Regularly busy days
# 92  Mid-range product  Regularly busy  Regularly busy days
# 93  Mid-range product  Regularly busy  Regularly busy days
# 94  Mid-range product  Regularly busy  Regularly busy days
# 95  Mid-range product  Regularly busy  Regularly busy days
# 96  Mid-range product  Regularly busy  Regularly busy days
# 97  Mid-range product      Least busy      Least busy days
# 98  Mid-range product  Regularly busy         Busiest days
# 99  Mid-range product  Regularly busy      Least busy days
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2            Most orders        10
# 3         Average orders        10
# 4            Most orders        10
# 5         Average orders        10
# 6            Most orders        10
# 7            Most orders        10
# 8            Most orders        10
# 9         Average orders        10
# 10           Most orders        22
# 11           Most orders        22
# 12           Most orders        22
# 13           Most orders        22
# 14           Most orders        22
# 15           Most orders         9
# 16           Most orders         9
# 17        Average orders         9
# 18           Most orders        33
# 19        Average orders        20
# 20           Most orders        20
# 21           Most orders        11
# 22           Most orders        11
# 23           Most orders        27
# 24           Most orders        27
# 25           Most orders        27
# 26           Most orders        27
# 27        Average orders        27
# 28           Most orders        27
# 29           Most orders        27
# 30           Most orders        27
# 31           Most orders        27
# 32           Most orders        27
# 33           Most orders        27
# 34           Most orders        27
# 35        Average orders        27
# 36           Most orders        27
# 37           Most orders        24
# 38           Most orders        24
# 39           Most orders        24
# 40           Most orders        24
# 41           Most orders        24
# 42           Most orders        24
# 43           Most orders        24
# 44           Most orders        24
# 45           Most orders        24
# 46           Most orders        24
# 47           Most orders        24
# 48           Most orders        24
# 49           Most orders        24
# 50           Most orders        24
# 51           Most orders        24
# 52           Most orders        24
# 53           Most orders        24
# 54           Most orders        24
# 55           Most orders        24
# 56           Most orders         7
# 57        Average orders         7
# 58           Most orders        19
# 59           Most orders        19
# 60           Most orders        19
# 61           Most orders        19
# 62           Most orders        19
# 63           Most orders        19
# 64           Most orders        19
# 65           Most orders        19
# 66           Most orders        19
# 67           Most orders        14
# 68           Most orders        14
# 69           Most orders        14
# 70           Most orders        14
# 71           Most orders        14
# 72           Most orders        14
# 73        Average orders        14
# 74        Average orders         6
# 75           Most orders         3
# 76        Average orders         3
# 77           Most orders         6
# 78           Most orders        58
# 79           Most orders        58
# 80           Most orders        58
# 81           Most orders        58
# 82           Most orders        58
# 83        Average orders        58
# 84           Most orders        58
# 85           Most orders        58
# 86           Most orders        58
# 87           Most orders        58
# 88           Most orders        58
# 89           Most orders        58
# 90           Most orders        70
# 91           Most orders        70
# 92        Average orders        51
# 93           Most orders        51
# 94           Most orders         8
# 95           Most orders         3
# 96        Average orders         3
# 97           Most orders         8
# 98        Average orders        22
# 99        Average orders        22
#
# [100 rows x 21 columns]

# %% [markdown]
# #### 5. Deriving Columns with loc()

# %%
# Creating a new column, Loyal custimer
# Flag with loc function
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Value check, count conclusion
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Check multiple columns at the same time with new synta
# loyalty flag + check the basic statistics of the product prices for each loyalty category
print('The mean, min and max of prices grouped by the loyalty_flag column in df_orders_products_merged:')
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
# The mean, min and max of prices grouped by the loyalty_flag column in df_orders_products_merged:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# No visible difference in the comparison of the three groups regarding the lowest and highest value spent. The Average of New customers is higher than the Average from Loyal customers group, This is surprising, but at the same time it translates into a potential increase in loyal customers.

# %% [markdown]
# #### 6. Create a spending flag

# %%
# Group by prices
ords_prods_merge.groupby('prices')

# %%
# Aggregated mean of the “loyalty_flag” column grouped by “prices” for whole dataframe
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                      prices
#                        mean
# loyalty_flag
# Loyal customer    10.386336
# New customer      13.294670
# Regular customer  12.495717

# %%
# Grouping the dataframe by 'user_id' and 'prices'
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
#  Output check
ords_prods_merge.shape
# Out:
# (32404859, 23)

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# 11   1870022       15    prior            17          2                 16
# 12   1911383       15    prior            18          2                 11
# 13   2715276       15    prior            21          1                  9
# 14    487368       15    prior            22          1                 10
# 15   2293453       19    prior             2          5                 14
# 16   1973799       19    prior             5          6                 12
# 17    532817       19    prior             7          4                 17
# 18   1573906       21    prior            10          3                 10
# 19   1593000       31    prior            10          3                  8
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                      NaN         196                  1          0  ...
# 1                     15.0         196                  1          1  ...
# 2                     21.0         196                  1          1  ...
# 3                     29.0         196                  1          1  ...
# 4                     28.0         196                  1          1  ...
# 5                     19.0         196                  1          1  ...
# 6                     20.0         196                  1          1  ...
# 7                     14.0         196                  2          1  ...
# 8                      0.0         196                  4          1  ...
# 9                     30.0         196                  1          1  ...
# 10                     7.0         196                  2          0  ...
# 11                     8.0         196                  6          1  ...
# 12                     7.0         196                  1          1  ...
# 13                     7.0         196                  1          1  ...
# 14                    14.0         196                  1          1  ...
# 15                     6.0         196                  3          0  ...
# 16                     8.0         196                 15          1  ...
# 17                     6.0         196                  1          1  ...
# 18                     6.0         196                  2          0  ...
# 19                     7.0         196                 17          0  ...
#
#    prices  _merge   price_range_loc    price_range_loc     busiest_day  \
# 0     9.0    both               NaN  Mid-range product  Regularly busy
# 1     9.0    both               NaN  Mid-range product  Regularly busy
# 2     9.0    both               NaN  Mid-range product  Regularly busy
# 3     9.0    both               NaN  Mid-range product      Least busy
# 4     9.0    both               NaN  Mid-range product      Least busy
# 5     9.0    both               NaN  Mid-range product  Regularly busy
# 6     9.0    both               NaN  Mid-range product  Regularly busy
# 7     9.0    both               NaN  Mid-range product  Regularly busy
# 8     9.0    both               NaN  Mid-range product  Regularly busy
# 9     9.0    both               NaN  Mid-range product      Least busy
# 10    9.0    both               NaN  Mid-range product  Regularly busy
# 11    9.0    both               NaN  Mid-range product  Regularly busy
# 12    9.0    both               NaN  Mid-range product  Regularly busy
# 13    9.0    both               NaN  Mid-range product  Regularly busy
# 14    9.0    both               NaN  Mid-range product  Regularly busy
# 15    9.0    both               NaN  Mid-range product  Regularly busy
# 16    9.0    both               NaN  Mid-range product  Regularly busy
# 17    9.0    both               NaN  Mid-range product      Least busy
# 18    9.0    both               NaN  Mid-range product  Regularly busy
# 19    9.0    both               NaN  Mid-range product  Regularly busy
#
#            busiest_days busiest_period_of_day max_order      loyalty_flag  \
# 0   Regularly busy days        Average orders        10      New customer
# 1       Least busy days        Average orders        10      New customer
# 2       Least busy days           Most orders        10      New customer
# 3       Least busy days        Average orders        10      New customer
# 4       Least busy days           Most orders        10      New customer
# 5   Regularly busy days        Average orders        10      New customer
# 6          Busiest days           Most orders        10      New customer
# 7          Busiest days           Most orders        10      New customer
# 8          Busiest days           Most orders        10      New customer
# 9       Least busy days        Average orders        10      New customer
# 10         Busiest days           Most orders        22  Regular customer
# 11  Regularly busy days           Most orders        22  Regular customer
# 12  Regularly busy days           Most orders        22  Regular customer
# 13         Busiest days           Most orders        22  Regular customer
# 14         Busiest days           Most orders        22  Regular customer
# 15  Regularly busy days           Most orders         9      New customer
# 16  Regularly busy days           Most orders         9      New customer
# 17      Least busy days        Average orders         9      New customer
# 18      Least busy days           Most orders        33  Regular customer
# 19      Least busy days        Average orders        20  Regular customer
#
#    average_price
# 0       6.367797
# 1       6.367797
# 2       6.367797
# 3       6.367797
# 4       6.367797
# 5       6.367797
# 6       6.367797
# 7       6.367797
# 8       6.367797
# 9       6.367797
# 10      3.980556
# 11      3.980556
# 12      3.980556
# 13      3.980556
# 14      3.980556
# 15      8.372059
# 16      8.372059
# 17      8.372059
# 18      7.012683
# 19      8.137793
#
# [20 rows x 23 columns]

# %%
# Creating a new column, Average_price
# Spending Flag with loc function
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'Spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'Spending_flag'] = 'High spender'

# %%
# Value check, count conclusion
ords_prods_merge['Spending_flag'].value_counts(dropna = False)
# Out:
# Spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %% [markdown]
# #### 7. Create an order frequency flag

# %%
# Grouping the dataframe by 'user_id' and 'days_since_prior_order'
ords_prods_merge['median_days_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
#  Output check
ords_prods_merge.shape
# Out:
# (32404859, 25)

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# 11   1870022       15    prior            17          2                 16
# 12   1911383       15    prior            18          2                 11
# 13   2715276       15    prior            21          1                  9
# 14    487368       15    prior            22          1                 10
# 15   2293453       19    prior             2          5                 14
# 16   1973799       19    prior             5          6                 12
# 17    532817       19    prior             7          4                 17
# 18   1573906       21    prior            10          3                 10
# 19   1593000       31    prior            10          3                  8
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                      NaN         196                  1          0  ...
# 1                     15.0         196                  1          1  ...
# 2                     21.0         196                  1          1  ...
# 3                     29.0         196                  1          1  ...
# 4                     28.0         196                  1          1  ...
# 5                     19.0         196                  1          1  ...
# 6                     20.0         196                  1          1  ...
# 7                     14.0         196                  2          1  ...
# 8                      0.0         196                  4          1  ...
# 9                     30.0         196                  1          1  ...
# 10                     7.0         196                  2          0  ...
# 11                     8.0         196                  6          1  ...
# 12                     7.0         196                  1          1  ...
# 13                     7.0         196                  1          1  ...
# 14                    14.0         196                  1          1  ...
# 15                     6.0         196                  3          0  ...
# 16                     8.0         196                 15          1  ...
# 17                     6.0         196                  1          1  ...
# 18                     6.0         196                  2          0  ...
# 19                     7.0         196                 17          0  ...
#
#     price_range_loc    price_range_loc     busiest_day         busiest_days  \
# 0               NaN  Mid-range product  Regularly busy  Regularly busy days
# 1               NaN  Mid-range product  Regularly busy      Least busy days
# 2               NaN  Mid-range product  Regularly busy      Least busy days
# 3               NaN  Mid-range product      Least busy      Least busy days
# 4               NaN  Mid-range product      Least busy      Least busy days
# 5               NaN  Mid-range product  Regularly busy  Regularly busy days
# 6               NaN  Mid-range product  Regularly busy         Busiest days
# 7               NaN  Mid-range product  Regularly busy         Busiest days
# 8               NaN  Mid-range product  Regularly busy         Busiest days
# 9               NaN  Mid-range product      Least busy      Least busy days
# 10              NaN  Mid-range product  Regularly busy         Busiest days
# 11              NaN  Mid-range product  Regularly busy  Regularly busy days
# 12              NaN  Mid-range product  Regularly busy  Regularly busy days
# 13              NaN  Mid-range product  Regularly busy         Busiest days
# 14              NaN  Mid-range product  Regularly busy         Busiest days
# 15              NaN  Mid-range product  Regularly busy  Regularly busy days
# 16              NaN  Mid-range product  Regularly busy  Regularly busy days
# 17              NaN  Mid-range product      Least busy      Least busy days
# 18              NaN  Mid-range product  Regularly busy      Least busy days
# 19              NaN  Mid-range product  Regularly busy      Least busy days
#
#    busiest_period_of_day max_order      loyalty_flag average_price  \
# 0         Average orders        10      New customer      6.367797
# 1         Average orders        10      New customer      6.367797
# 2            Most orders        10      New customer      6.367797
# 3         Average orders        10      New customer      6.367797
# 4            Most orders        10      New customer      6.367797
# 5         Average orders        10      New customer      6.367797
# 6            Most orders        10      New customer      6.367797
# 7            Most orders        10      New customer      6.367797
# 8            Most orders        10      New customer      6.367797
# 9         Average orders        10      New customer      6.367797
# 10           Most orders        22  Regular customer      3.980556
# 11           Most orders        22  Regular customer      3.980556
# 12           Most orders        22  Regular customer      3.980556
# 13           Most orders        22  Regular customer      3.980556
# 14           Most orders        22  Regular customer      3.980556
# 15           Most orders         9      New customer      8.372059
# 16           Most orders         9      New customer      8.372059
# 17        Average orders         9      New customer      8.372059
# 18           Most orders        33  Regular customer      7.012683
# 19        Average orders        20  Regular customer      8.137793
#
#    Spending_flag median_days_order
# 0    Low spender              20.5
# 1    Low spender              20.5
# 2    Low spender              20.5
# 3    Low spender              20.5
# 4    Low spender              20.5
# 5    Low spender              20.5
# 6    Low spender              20.5
# 7    Low spender              20.5
# 8    Low spender              20.5
# 9    Low spender              20.5
# 10   Low spender              10.0
# 11   Low spender              10.0
# 12   Low spender              10.0
# 13   Low spender              10.0
# 14   Low spender              10.0
# 15   Low spender               6.0
# 16   Low spender               6.0
# 17   Low spender               6.0
# 18   Low spender               7.5
# 19   Low spender               6.0
#
# [20 rows x 25 columns]

# %%
# Frequency Flag with loc function in three criteria
ords_prods_merge.loc[ords_prods_merge['median_days_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_order'] > 10) & (ords_prods_merge['median_days_order'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_order'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Value check, count conclusion
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
# Print Not a Number, NaN values
print(ords_prods_merge[ords_prods_merge.frequency_flag.isnull()])
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 13645692    895835   159838    prior             1          0
# 17251990    895835   159838    prior             1          0
# 17622767    895835   159838    prior             1          0
# 24138593    895835   159838    prior             1          0
# 25880002    895835   159838    prior             1          0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 13645692                 17                     NaN       10749
# 17251990                 17                     NaN       33401
# 17622767                 17                     NaN       23695
# 24138593                 17                     NaN       21334
# 25880002                 17                     NaN       22198
#
#           add_to_cart_order  reordered  ...    price_range_loc  busiest_day  \
# 13645692                  3          0  ...  Mid-range product  Busiest day
# 17251990                  6          0  ...  Mid-range product  Busiest day
# 17622767                  2          0  ...  Low-range product  Busiest day
# 24138593                  5          0  ...  Mid-range product  Busiest day
# 25880002                  1          0  ...  Low-range product  Busiest day
#
#           busiest_days  busiest_period_of_day max_order  loyalty_flag  \
# 13645692  Busiest days         Average orders         1  New customer
# 17251990  Busiest days         Average orders         1  New customer
# 17622767  Busiest days         Average orders         1  New customer
# 24138593  Busiest days         Average orders         1  New customer
# 25880002  Busiest days         Average orders         1  New customer
#
#          average_price Spending_flag median_days_order frequency_flag
# 13645692          7.42   Low spender               NaN            NaN
# 17251990          7.42   Low spender               NaN            NaN
# 17622767          7.42   Low spender               NaN            NaN
# 24138593          7.42   Low spender               NaN            NaN
# 25880002          7.42   Low spender               NaN            NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# These are 5 new customers, they do not have average orders (median_days_order), but they can be matched in the 'frequency_flag' column to Non-frequent customer.

# %%
# Correcting the NaN values in 'frequency_flag' column
ords_prods_merge['frequency_flag'].fillna("Non-frequent customer", inplace = True)

# %%
# Secound check, count conclusion
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636442
# Name: count, dtype: int64

# %%
# Export data to pkl
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_agg.pkl'))
